# %% [markdown]
# Tensorflow GPU 使用測試

# %%
# pip install tensorflow

# %%
import tensorflow as tf

# %%
print("Num GPUs Available:", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available: 1

# %%
# 顯示 TensorFlow 使用的設備
print("Is GPU Available:", tf.test.is_gpu_available())
# Out:
# WARNING:tensorflow:From <ipython-input-3-abf262ec4cc5>:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# Is GPU Available: True

# %%
# 顯示 GPU 名稱（如果可用）
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if gpu_devices:
  print("GPU Device Name:", tf.config.experimental.get_device_details(gpu_devices[0])["device_name"])
# Out:
# GPU Device Name: Tesla T4

# %% [markdown]
# 影像訓練簡易程式

# %%
import tensorflow as tf
import numpy as np

# 檢查 GPU 是否可用
device_name = "GPU" if tf.config.list_physical_devices('GPU') else "CPU"
print(f"Using device: {device_name}")

# 生成隨機圖像數據 (1000 張 32x32x3 的圖片，共 10 類)
num_classes = 10
X_train = np.random.rand(1000, 32, 32, 3).astype(np.float32)  # 訓練數據
y_train = np.random.randint(0, num_classes, 1000)  # 訓練標籤

X_test = np.random.rand(200, 32, 32, 3).astype(np.float32)  # 測試數據
y_test = np.random.randint(0, num_classes, 200)  # 測試標籤

# 將標籤轉換為 One-Hot
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# 建立簡單的 CNN 模型
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(16, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

# 編譯模型
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 訓練 5 個 epoch
model.fit(X_train, y_train, epochs=5, batch_size=32, validation_data=(X_test, y_test))

# 測試模型
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print(f"Test Accuracy: {test_acc:.2%}")
# Out:
# Using device: GPU
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.1168 - loss: 2.4270 - val_accuracy: 0.1250 - val_loss: 2.3215
# Epoch 2/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1525 - loss: 2.2641 - val_accuracy: 0.0850 - val_loss: 2.3261
# Epoch 3/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2597 - loss: 2.1931 - val_accuracy: 0.0950 - val_loss: 2.3616
# Epoch 4/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2639 - loss: 2.1005 - val_accuracy: 0.0700 - val_loss: 2.4251
# Epoch 5/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3739 - loss: 1.9886 - val_accuracy: 0.0850 - val_loss: 2.3815
# 7/7 - 0s - 6ms/step - accuracy: 0.0850 - loss: 2.3815
# Test Accuracy: 8.50%
